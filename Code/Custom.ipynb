# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls -lh "/content/drive/MyDrive/food.zip"
# Out:
# -rw------- 1 root root 1.5G Aug 12 08:12 /content/drive/MyDrive/food.zip

# %%
# !df -h /content
# Out:
# Filesystem      Size  Used Avail Use% Mounted on
# overlay         113G   47G   66G  42% /

# %%
import os

zip_path = "/content/drive/MyDrive/food.zip"
extract_path = "/content"

os.makedirs(extract_path, exist_ok=True)

# !unzip -q "$zip_path" -d "$extract_path"

print("Extraction completed!")
# Out:
# Extraction completed!

# %%
# !find "/content/food" -maxdepth 2 -type d | head -100
# Out:
# /content/food
# /content/food/valid
# /content/food/valid/ice_cream
# /content/food/valid/jalebi
# /content/food/valid/masala_dosa
# /content/food/valid/Sandwich
# /content/food/valid/paani_puri
# /content/food/valid/Baked Potato
# /content/food/valid/kadai_paneer
# /content/food/valid/pav_bhaji
# /content/food/valid/fried_rice
# /content/food/valid/dal_makhani
# /content/food/valid/sushi
# /content/food/valid/chicken_curry
# /content/food/valid/pizza
# /content/food/valid/Fries
# /content/food/valid/cheesecake
# /content/food/valid/butter_naan
# /content/food/valid/chapati
# /content/food/valid/momos
# /content/food/valid/samosa
# /content/food/valid/burger
# /content/food/valid/kaathi_rolls
# /content/food/valid/idli
# /content/food/valid/chai
# /content/food/valid/Taco
# /content/food/valid/dhokla
# /content/food/valid/Donut
# /content/food/valid/pakode
# /content/food/valid/chole_bhature
# /content/food/valid/Taquito
# /content/food/valid/Hot Dog
# /content/food/valid/Crispy Chicken
# /content/food/valid/kulfi
# /content/food/valid/omelette
# /content/food/valid/apple_pie
# /content/food/train
# /content/food/train/ice_cream
# /content/food/train/jalebi
# /content/food/train/masala_dosa
# /content/food/train/Sandwich
# /content/food/train/paani_puri
# /content/food/train/Baked Potato
# /content/food/train/kadai_paneer
# /content/food/train/pav_bhaji
# /content/food/train/fried_rice
# /content/food/train/dal_makhani
# /content/food/train/sushi
# /content/food/train/chicken_curry
# /content/food/train/pizza
# /content/food/train/Fries
# /content/food/train/cheesecake
# /content/food/train/butter_naan
# /content/food/train/chapati
# /content/food/train/momos
# /content/food/train/samosa
# /content/food/train/burger
# /content/food/train/kaathi_rolls
# /content/food/train/idli
# /content/food/train/chai
# /content/food/train/Taco
# /content/food/train/dhokla
# /content/food/train/Donut
# /content/food/train/pakode
# /content/food/train/chole_bhature
# /content/food/train/Taquito
# /content/food/train/Hot Dog
# /content/food/train/Crispy Chicken
# /content/food/train/kulfi
# /content/food/train/omelette
# /content/food/train/apple_pie
# /content/food/test
# /content/food/test/ice_cream
# /content/food/test/jalebi
# /content/food/test/masala_dosa
# /content/food/test/Sandwich
# /content/food/test/paani_puri
# /content/food/test/Baked Potato
# /content/food/test/kadai_paneer
# /content/food/test/pav_bhaji
# /content/food/test/fried_rice
# /content/food/test/dal_makhani
# /content/food/test/sushi
# /content/food/test/chicken_curry
# /content/food/test/pizza
# /content/food/test/Fries
# /content/food/test/cheesecake
# /content/food/test/butter_naan
# /content/food/test/chapati
# /content/food/test/momos
# /content/food/test/samosa
# /content/food/test/burger
# /content/food/test/kaathi_rolls
# /content/food/test/idli
# /content/food/test/chai
# /content/food/test/Taco
# /content/food/test/dhokla
# /content/food/test/Donut
# /content/food/test/pakode
# /content/food/test/chole_bhature

# %%
import os
os.listdir("/content/food/")
# Out:
# ['valid', 'train', 'test']

# %%
os.listdir("/content/food/train/")
# Out:
# ['ice_cream',
#  'jalebi',
#  'masala_dosa',
#  'Sandwich',
#  'paani_puri',
#  'Baked Potato',
#  'kadai_paneer',
#  'pav_bhaji',
#  'fried_rice',
#  'dal_makhani',
#  'sushi',
#  'chicken_curry',
#  'pizza',
#  'Fries',
#  'cheesecake',
#  'butter_naan',
#  'chapati',
#  'momos',
#  'samosa',
#  'burger',
#  'kaathi_rolls',
#  'idli',
#  'chai',
#  'Taco',
#  'dhokla',
#  'Donut',
#  'pakode',
#  'chole_bhature',
#  'Taquito',
#  'Hot Dog',
#  'Crispy Chicken',
#  'kulfi',
#  'omelette',
#  'apple_pie']

# %%
os.listdir("/content/food/test/")
# Out:
# ['ice_cream',
#  'jalebi',
#  'masala_dosa',
#  'Sandwich',
#  'paani_puri',
#  'Baked Potato',
#  'kadai_paneer',
#  'pav_bhaji',
#  'fried_rice',
#  'dal_makhani',
#  'sushi',
#  'chicken_curry',
#  'pizza',
#  'Fries',
#  'cheesecake',
#  'butter_naan',
#  'chapati',
#  'momos',
#  'samosa',
#  'burger',
#  'kaathi_rolls',
#  'idli',
#  'chai',
#  'Taco',
#  'dhokla',
#  'Donut',
#  'pakode',
#  'chole_bhature',
#  'Taquito',
#  'Hot Dog',
#  'Crispy Chicken',
#  'kulfi',
#  'omelette',
#  'apple_pie']

# %%
os.listdir("/content/food/valid/")
# Out:
# ['ice_cream',
#  'jalebi',
#  'masala_dosa',
#  'Sandwich',
#  'paani_puri',
#  'Baked Potato',
#  'kadai_paneer',
#  'pav_bhaji',
#  'fried_rice',
#  'dal_makhani',
#  'sushi',
#  'chicken_curry',
#  'pizza',
#  'Fries',
#  'cheesecake',
#  'butter_naan',
#  'chapati',
#  'momos',
#  'samosa',
#  'burger',
#  'kaathi_rolls',
#  'idli',
#  'chai',
#  'Taco',
#  'dhokla',
#  'Donut',
#  'pakode',
#  'chole_bhature',
#  'Taquito',
#  'Hot Dog',
#  'Crispy Chicken',
#  'kulfi',
#  'omelette',
#  'apple_pie']

# %%
os.listdir("/content/food/train/Donut/")
# Out:
# ['Donut (1353).jpeg',
#  'Donut (345).jpeg',
#  'Donut (352).jpeg',
#  'Donut (1216).jpeg',
#  'Donut (597).jpeg',
#  'Donut (613).jpeg',
#  'Donut (1232).jpeg',
#  'Donut (1012).jpeg',
#  'Donut (131).jpeg',
#  'Donut (737).jpeg',
#  'Donut (952).jpeg',
#  'Donut (572).jpeg',
#  'Donut (74).jpeg',
#  'Donut (1038).jpeg',
#  'Donut (897).jpeg',
#  'Donut (1051).jpeg',
#  'Donut (343).jpeg',
#  'Donut (1407).jpeg',
#  'Donut (465).jpeg',
#  'Donut (1461).jpeg',
#  'Donut (826).jpeg',
#  'Donut (217).jpeg',
#  'Donut (1316).jpeg',
#  'Donut (1359).jpeg',
#  'Donut (76).jpeg',
#  'Donut (1390).jpeg',
#  'Donut (1162).jpeg',
#  'Donut (1309).jpeg',
#  'Donut (775).jpeg',
#  'Donut (428).jpeg',
#  'Donut (971).jpeg',
#  'Donut (1260).jpeg',
#  'Donut (1230).jpeg',
#  'Donut (690).jpeg',
#  'Donut (567).jpeg',
#  'Donut (5).jpeg',
#  'Donut (109).jpeg',
#  'Donut (1379).jpeg',
#  'Donut (1256).jpeg',
#  'Donut (1290).jpeg',
#  'Donut (399).jpeg',
#  'Donut (1337).jpeg',
#  'Donut (1167).jpeg',
#  'Donut (1326).jpeg',
#  'Donut (888).jpeg',
#  'Donut (32).jpg',
#  'Donut (22).jpeg',
#  'Donut (687).jpeg',
#  'Donut (1085).jpeg',
#  'Donut (1226).jpeg',
#  'Donut (756).jpeg',
#  'Donut (114).jpeg',
#  'Donut (903).jpeg',
#  'Donut (525).jpeg',
#  'Donut (534).jpeg',
#  'Donut (96).jpeg',
#  'Donut (1257).jpeg',
#  'Donut (846).jpeg',
#  'Donut (863).jpeg',
#  'Donut (1458).jpeg',
#  'Donut (1445).jpeg',
#  'Donut (39).jpeg',
#  'Donut (1320).jpeg',
#  'Donut (633).jpeg',
#  'Donut (689).jpeg',
#  'Donut (42).jpeg',
#  'Donut (1165).jpeg',
#  'Donut (752).jpeg',
#  'Donut (346).jpeg',
#  'Donut (11).jpg',
#  'Donut (154).jpeg',
#  'Donut (672).jpeg',
#  'Donut (1001).jpeg',
#  'Donut (4).jpg',
#  'Donut (1273).jpeg',
#  'Donut (1451).jpeg',
#  'Donut (568).jpeg',
#  'Donut (1062).jpeg',
#  'Donut (164).jpeg',
#  'Donut (334).jpeg',
#  'Donut (912).jpeg',
#  'Donut (872).jpeg',
#  'Donut (1331).jpeg',
#  'Donut (378).jpeg',
#  'Donut (82).jpeg',
#  'Donut (87).jpeg',
#  'Donut (713).jpeg',
#  'Donut (30).jpg',
#  'Donut (497).jpeg',
#  'Donut (1092).jpeg',
#  'Donut (1391).jpeg',
#  'Donut (110).jpeg',
#  'Donut (596).jpeg',
#  'Donut (1418).jpeg',
#  'Donut (136).jpeg',
#  'Donut (1275).jpeg',
#  'Donut (94).jpeg',
#  'Donut (493).jpeg',
#  'Donut (1221).jpeg',
#  'Donut (808).jpeg',
#  'Donut (1044).jpeg',
#  'Donut (37).png',
#  'Donut (571).jpeg',
#  'Donut (286).jpeg',
#  'Donut (593).jpeg',
#  'Donut (1284).jpeg',
#  'Donut (1243).jpeg',
#  'Donut (1358).jpeg',
#  'Donut (291).jpeg',
#  'Donut (921).jpeg',
#  'Donut (876).jpeg',
#  'Donut (341).jpeg',
#  'Donut (920).jpeg',
#  'Donut (997).jpeg',
#  'Donut (817).jpeg',
#  'Donut (24).jpeg',
#  'Donut (857).jpeg',
#  'Donut (176).jpeg',
#  'Donut (570).jpeg',
#  'Donut (360).jpeg',
#  'Donut (499).jpeg',
#  'Donut (361).jpeg',
#  'Donut (1239).jpeg',
#  'Donut (227).jpeg',
#  'Donut (1084).jpeg',
#  'Donut (1245).jpeg',
#  'Donut (155).jpeg',
#  'Donut (430).jpeg',
#  'Donut (1014).jpeg',
#  'Donut (972).jpeg',
#  'Donut (1176).jpeg',
#  'Donut (848).jpeg',
#  'Donut (990).jpeg',
#  'Donut (589).jpeg',
#  'Donut (469).jpeg',
#  'Donut (1369).jpeg',
#  'Donut (1448).jpeg',
#  'Donut (1203).jpeg',
#  'Donut (49).jpeg',
#  'Donut (1196).jpeg',
#  'Donut (1095).jpeg',
#  'Donut (1111).jpeg',
#  'Donut (664).jpeg',
#  'Donut (543).jpeg',
#  'Donut (842).jpeg',
#  'Donut (909).jpeg',
#  'Donut (547).jpeg',
#  'Donut (885).jpeg',
#  'Donut (1020).jpeg',
#  'Donut (439).jpeg',
#  'Donut (40).jpg',
#  'Donut (386).jpeg',
#  'Donut (468).jpeg',
#  'Donut (276).jpeg',
#  'Donut (180).jpeg',
#  'Donut (314).jpeg',
#  'Donut (675).jpeg',
#  'Donut (160).jpeg',
#  'Donut (422).jpeg',
#  'Donut (870).jpeg',
#  'Donut (466).jpeg',
#  'Donut (631).jpeg',
#  'Donut (149).jpeg',
#  'Donut (1449).jpeg',
#  'Donut (245).jpeg',
#  'Donut (337).jpeg',
#  'Donut (762).jpeg',
#  'Donut (1140).jpeg',
#  'Donut (142).jpeg',
#  'Donut (239).jpeg',
#  'Donut (558).jpeg',
#  'Donut (72).jpeg',
#  'Donut (692).jpeg',
#  'Donut (104).jpeg',
#  'Donut (1191).jpeg',
#  'Donut (10).jpg',
#  'Donut (262).jpeg',
#  'Donut (564).jpeg',
#  'Donut (1110).jpeg',
#  'Donut (492).jpeg',
#  'Donut (1102).jpeg',
#  'Donut (391).jpeg',
#  'Donut (117).jpeg',
#  'Donut (650).jpeg',
#  'Donut (55).jpeg',
#  'Donut (298).jpeg',
#  'Donut (902).jpeg',
#  'Donut (61).jpeg',
#  'Donut (34).jpeg',
#  'Donut (416).jpeg',
#  'Donut (736).jpeg',
#  'Donut (946).jpeg',
#  'Donut (1041).jpeg',
#  'Donut (1405).jpeg',
#  'Donut (819).jpeg',
#  'Donut (1004).jpeg',
#  'Donut (632).jpeg',
#  'Donut (1348).jpeg',
#  'Donut (42).jpg',
#  'Donut (1123).jpeg',
#  'Donut (1188).jpeg',
#  'Donut (893).jpeg',
#  'Donut (501).jpeg',
#  'Donut (1428).jpeg',
#  'Donut (1139).jpeg',
#  'Donut (522).jpeg',
#  'Donut (503).jpeg',
#  'Donut (367).jpeg',
#  'Donut (279).jpeg',
#  'Donut (1322).jpeg',
#  'Donut (845).jpeg',
#  'Donut (556).jpeg',
#  'Donut (1121).jpeg',
#  'Donut (143).jpeg',
#  'Donut (1318).jpeg',
#  'Donut (804).jpeg',
#  'Donut (592).jpeg',
#  'Donut (339).jpeg',
#  'Donut (431).jpeg',
#  'Donut (32).jpeg',
#  'Donut (242).jpeg',
#  'Donut (152).jpeg',
#  'Donut (83).jpeg',
#  'Donut (7).jpg',
#  'Donut (977).jpeg',
#  'Donut (38).png',
#  'Donut (198).jpeg',
#  'Donut (1204).jpeg',
#  'Donut (1250).jpeg',
#  'Donut (896).jpeg',
#  'Donut (39).jpg',
#  'Donut (1408).jpeg',
#  'Donut (680).jpeg',
#  'Donut (93).jpeg',
#  'Donut (1393).jpeg',
#  'Donut (1090).jpeg',
#  'Donut (409).jpeg',
#  'Donut (250).jpeg',
#  'Donut (739).jpeg',
#  'Donut (1197).jpeg',
#  'Donut (622).jpeg',
#  'Donut (1081).jpeg',
#  'Donut (271).jpeg',
#  'Donut (302).jpeg',
#  'Donut (835).jpeg',
#  'Donut (1259).jpeg',
#  'Donut (573).jpeg',
#  'Donut (97).jpeg',
#  'Donut (764).jpeg',
#  'Donut (126).jpeg']

# %%
os.listdir("/content/food/test/Donut/")
# Out:
# ['Donut (181).jpeg',
#  'Donut (1304).jpeg',
#  'Donut (423).jpeg',
#  'Donut (285).jpeg',
#  'Donut (837).jpeg',
#  'Donut (800).jpeg',
#  'Donut (1292).jpeg',
#  'Donut (1450).jpeg',
#  'Donut (506).jpeg',
#  'Donut (603).jpeg',
#  'Donut (961).jpeg',
#  'Donut (627).jpeg',
#  'Donut (1068).jpeg',
#  'Donut (51).jpg',
#  'Donut (310).jpeg',
#  'Donut (854).jpeg',
#  'Donut (1076).jpeg',
#  'Donut (203).jpeg',
#  'Donut (22).jpg',
#  'Donut (874).jpeg']

# %%
os.listdir("/content/food/valid/Donut/")
# Out:
# ['Donut (698).jpeg',
#  'Donut (979).jpeg',
#  'Donut (530).jpeg',
#  'Donut (1378).jpeg',
#  'Donut (1342).jpeg',
#  'Donut (448).jpeg',
#  'Donut (654).jpeg',
#  'Donut (6).jpeg',
#  'Donut (252).jpeg',
#  'Donut (1442).jpeg',
#  'Donut (268).jpeg',
#  'Donut (1175).jpeg',
#  'Donut (1035).jpeg',
#  'Donut (3).jpeg',
#  'Donut (1011).jpeg',
#  'Donut (1128).jpeg',
#  'Donut (1043).jpeg',
#  'Donut (1277).jpeg',
#  'Donut (64).jpeg',
#  'Donut (1262).jpeg',
#  'Donut (220).jpeg',
#  'Donut (490).jpeg',
#  'Donut (163).jpeg',
#  'Donut (915).jpeg',
#  'Donut (1446).jpeg',
#  'Donut (233).jpeg',
#  'Donut (75).jpeg',
#  'Donut (1368).jpeg',
#  'Donut (865).jpeg',
#  'Donut (609).jpeg',
#  'Donut (173).jpeg',
#  'Donut (901).jpeg',
#  'Donut (884).jpeg',
#  'Donut (831).jpeg',
#  'Donut (850).jpeg',
#  'Donut (565).jpeg',
#  'Donut (427).jpeg',
#  'Donut (295).jpeg',
#  'Donut (1482).jpeg',
#  'Donut (23).jpg',
#  'Donut (139).jpeg',
#  'Donut (1179).jpeg',
#  'Donut (1409).jpeg',
#  'Donut (1042).jpeg',
#  'Donut (996).jpeg',
#  'Donut (48).jpeg',
#  'Donut (269).jpeg',
#  'Donut (1233).jpeg',
#  'Donut (111).jpeg',
#  'Donut (1158).jpeg']

# %%
train_data_path="/content/food/train"
valid_data_path="/content/food/valid"
test_data_path="/content/food/test"

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(5,5))
plt.title("Baked Potato")
baked_potato=plt.imread(train_data_path+"/Baked Potato/Baked Potato-Train (100).jpeg")
plt.imshow(baked_potato)
plt.show()

# %%
plt.figure(figsize=(5,5))
plt.title("Apple")
apple_pie=plt.imread(train_data_path+"/apple_pie/1043283.jpg")
plt.imshow(apple_pie)
plt.show()

# %%
label_names=['Baked Potato','Crispy Chicken','Donut','Fries','Hot Dog','Sandwich','Taco','Taquito','apple_pie','burger','butter_naan','chai','chapati','cheesecake','chicken_curry','chole_bhature','dal_makhani','dhokla','fried_rice','ice_cream','idli','jalebi','kaathi_rolls','kadai_paneer','kulfi','masala_dosa','momos','omelette','paani_puri','pakode','pav_bhaji','pizza','samosa','sushi']

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
train_data_rules = ImageDataGenerator(rescale = 1 / 255.0 ,
                                      rotation_range = 0.2 ,
                                      shear_range=0.2 ,
                                      horizontal_flip = True)

val_data_rules = ImageDataGenerator(rescale = 1 / 255.0 ,
                                      rotation_range = 0.2 ,
                                      shear_range=0.2 ,
                                      horizontal_flip = True)

# %%
final_train_data = train_data_rules.flow_from_directory(train_data_path , target_size=(256,256) ,
                                     color_mode='rgb',
                                     classes=label_names , class_mode='categorical')

final_val_data = val_data_rules.flow_from_directory(valid_data_path , target_size=(256,256) ,
                                     color_mode='rgb',
                                     classes=label_names , class_mode='categorical')
# Out:
# Found 8500 images belonging to 34 classes.
# Found 1700 images belonging to 34 classes.

# %% [markdown]
# Custom Architecture

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D,MaxPooling2D,Dense,Flatten
from tensorflow.keras.activations import relu,softmax

# %%
model=Sequential()
model.add(Conv2D(256,kernel_size=(3,3),
                 kernel_initializer='he_uniform',
                 activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Conv2D(128,kernel_size=(3,3),
                 kernel_initializer='he_uniform',
                 activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Conv2D(64,kernel_size=(3,3),
                 kernel_initializer='he_uniform',
                 activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Flatten())

#ANN
model.add(Dense(units=50,
                kernel_initializer='he_uniform',
                activation='relu'))
model.add(Dense(units=42,
                kernel_initializer='he_uniform',
                activation='relu'))
model.add(Dense(units=38,
                kernel_initializer='he_uniform',
                activation='relu'))
model.add(Dense(units=34,
                kernel_initializer='glorot_uniform',
                activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ ?                      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ ?                      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ ?                      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['Accuracy'])

# %%
model.fit(final_train_data,
          validation_data=final_val_data,
          batch_size=32,
          epochs=50)
# Out:
# Epoch 1/50
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 300s 1s/step - Accuracy: 0.0344 - loss: 3.5676 - val_Accuracy: 0.0288 - val_loss: 3.5129
# Epoch 2/50
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 249s 936ms/step - Accuracy: 0.0405 - loss: 3.5027 - val_Accuracy: 0.0424 - val_loss: 3.5340
# Epoch 3/50
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 245s 920ms/step - Accuracy: 0.0567 - loss: 3.4618 - val_Accuracy: 0.0506 - val_loss: 3.4948
# Epoch 4/50
# 266/266 ━━━━━━━━━━━━━━━━━━━━
50
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 248s 933ms/step - Accuracy: 0.9291 - loss: 0.2952 - val_Accuracy: 0.0888 - val_loss: 13.9028
# Epoch 50/50
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 247s 928ms/step - Accuracy: 0.9351 - loss: 0.2590 - val_Accuracy: 0.0947 - val_loss: 13.8753

# %%
import cv2

# %%
def testing_function(image_path):
  t_image = cv2.imread(image_path,1)
  print(f"Original_image size : {t_image.shape}")
  resized_image = cv2.resize(t_image , (256,256))
  print(f"Resized Image size : {resized_image.shape}")
  scaled_down_image = resized_image / 255.0
  print(f"After Scaling : {scaled_down_image.shape}")
  added_dim_image = np.expand_dims(scaled_down_image , axis=0)
  print(f"After Adding 1 Dim size : {added_dim_image.shape}")
  print(label_names[np.argmax(model.predict(added_dim_image))])

  plt.imshow(t_image[: , : ,::-1])
  plt.show()

# %%
testing_function("/content/food/test/Donut/Donut (1068).jpeg")
# Out:
# Original_image size : (225, 225, 3)
# Resized Image size : (256, 256, 3)
# After Scaling : (256, 256, 3)
# After Adding 1 Dim size : (1, 256, 256, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Donut

# %%
testing_function("/content/food/test/butter_naan/024.JPG")
# Out:
# Original_image size : (520, 520, 3)
# Resized Image size : (256, 256, 3)
# After Scaling : (256, 256, 3)
# After Adding 1 Dim size : (1, 256, 256, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# chapati

# %%
testing_function("/content/food/test/chicken_curry/1052361.jpg")
# Out:
# Original_image size : (512, 512, 3)
# Resized Image size : (256, 256, 3)
# After Scaling : (256, 256, 3)
# After Adding 1 Dim size : (1, 256, 256, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# Taco

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 254, 254, 256)  │         7,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 127, 127, 256)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 125, 125, 128)  │       295,040 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 62, 62, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 60, 60, 64)     │        73,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 30, 30, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 57600)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 50)             │     2,880,050 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 42)             │         2,142 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 38)             │         1,634 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 34)             │         1,326 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 9,783,458 (37.32 MB)
#  Trainable params: 3,261,152 (12.44 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 6,522,306 (24.88 MB)

# %%
import torch

# %%
model.save("custom_model.keras")

# %%
model.save_weights("custom_model.weights.h5")

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

test_data_rules = ImageDataGenerator(
    rescale=1 / 255.0
)

final_test_data = test_data_rules.flow_from_directory(
    test_data_path,
    target_size=(256, 256),
    color_mode="rgb",
    classes=label_names,
    class_mode="categorical",
    batch_size=16,
    shuffle=False
)
# Out:
# Found 680 images belonging to 34 classes.

# %%
import numpy as np

predictions = model.predict(final_test_data)

y_pred = np.argmax(predictions, axis=1)
y_true = final_test_data.classes
# Out:
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 13s 206ms/step

# %%
from sklearn.metrics import precision_recall_fscore_support

precision, recall, f1_score, support = precision_recall_fscore_support(
    y_true,
    y_pred,
    labels=np.arange(len(label_names)),
    zero_division=0
)

# %%
class_accuracy = []

for class_index in range(len(label_names)):

    class_mask = (y_true == class_index)

    correct_predictions = np.sum(
        y_pred[class_mask] == y_true[class_mask]
    )

    total_samples = np.sum(class_mask)

    accuracy = (
        correct_predictions / total_samples
        if total_samples > 0
        else 0
    )

    class_accuracy.append(accuracy)

# %%
import json

performance = {}

for i, class_name in enumerate(label_names):

    performance[class_name] = {
        "precision": round(float(precision[i]), 4),
        "recall": round(float(recall[i]), 4),
        "f1_score": round(float(f1_score[i]), 4),
        "accuracy": round(float(class_accuracy[i]), 4),
        "support": int(support[i])
    }

with open("custom_model_performance.json", "w") as file:
    json.dump(performance, file, indent=4)

print("Class-wise performance metrics saved successfully!")
# Out:
# Class-wise performance metrics saved successfully!
